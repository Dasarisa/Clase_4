# %%
from pylab import imshow, show, xlabel, ylabel
from numpy import loadtxt

data = loadtxt("/home/usuario/DanielRico/unidad1_IntroLinux/data/circular.txt", float)
print(data.shape)
imshow(data)
show()

print("hola")
# Out:
# (501, 501)
# hola

# %%
imshow(data, origin="lower")
xlabel("Index i")
ylabel("Index j")
show()

# %%
from pylab import gray, xlim, ylim
imshow(data, origin="lower")
gray()
#xlim(0., 50.)
#ylim(0., 50.)
show()
